# %% [markdown]
# ## **0. Tải bộ dữ liệu**
# **Lưu ý:** Nếu bạn không thể sử dụng lệnh gdown để tải bộ dữ liệu vì bị giới hạn số lượt tải, hãy tải bộ dữ liệu thử công và upload lên google drive của mình. Sau đó, sử dụng lệnh dưới đây để copy file dữ liệu vào colab:
# ```python
# from google.colab import drive
#
# drive.mount('/content/drive')
# !cp /path/to/dataset/on/your/drive .
# ```

# %%
# https://drive.google.com/file/d/11fjFxxa2RfoLCJUQ_OSTm3GfMZHVy8Gy/view?usp=sharing
# !gdown --id 11fjFxxa2RfoLCJUQ_OSTm3GfMZHVy8Gy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=136oQPFJqG0vugwm0oAOU9IxwJN0zT54K
# To: /content/Pokemon.csv
# 100% 44.0k/44.0k [00:00<00:00, 87.1MB/s]

# %% [markdown]
# ## **1. Import thư viện và load dataset**

# %%
import pandas as pd
import numpy as np

DATASET_PATH = '/content/Pokemon.csv'
data = pd.read_csv(DATASET_PATH)

# %%
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ## **3. Đọc dữ liệu đứng đầu**

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## **4. Đọc dữ liệu đứng cuối**

# %%
data.tail(8)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 792      131       98     99           6       True
# 793      131       98     99           6       True
# 794       81       95     95           6       True
# 795      100      150     50           6       True
# ...

# %% [markdown]
# ## **5. Lấy tên cột (headers)**

# %%
print(data.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ## **6. Đọc một cột cụ thể**

# %%
print(data[['Name']].head())
print('\n')
print(data[['Name', 'Total', 'Attack']][:10:2])
# Out:
#                     Name
# 0              Bulbasaur
# 1                Ivysaur
# 2               Venusaur
# 3  VenusaurMega Venusaur
# 4             Charmander
#
#
#                         Name  Total  Attack
# 0                  Bulbasaur    318      49
# 2                   Venusaur    525      82
# 4                 Charmander    309      52
# 6                  Charizard    534      84
# 8  CharizardMega Charizard Y    634     104

# %% [markdown]
# ## **7. Đọc một hàng cụ thể**

# %%
data.iloc[[3]]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3      122      120     80           1      False

# %%
data.iloc[[3,6]]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3      122      120     80           1      False
# 6      109       85    100           1      False

# %%
data.iloc[3:5]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data.loc[data['Legendary'] == True].head(2)
# Out:
#        #      Name    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 156  144  Articuno       Ice  Flying    580  90      85      100       95
# 157  145    Zapdos  Electric  Flying    580  90      90       85      125
#
#      Sp. Def  Speed  Generation  Legendary
# 156      125     85           1       True
# 157       90    100           1       True

# %% [markdown]
# ## **8. Đọc giá trị trong một hàng**

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data.iloc[3,4]
# Out:
# 625

# %%
data.loc[data['Attack'] == 49, ['Name']]
# Out:
#           Name
# 0    Bulbasaur
# 166  Chikorita
# 506    Finneon

# %% [markdown]
# ## **9. Lấy thông tin thống kê của bảng dữ liệu**

# %%
data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# ## **10. Sắp xếp bảng dữ liệu theo giá trị của cột**

# %%
data.sort_values('Type 1').head(3)
# Out:
#        #      Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 600  540  Sewaddle    Bug  Grass    310  45      53       70       40
# 136  127    Pinsir    Bug    NaN    500  65     125      100       55
# 457  412     Burmy    Bug    NaN    224  40      29       45       29
#
#      Sp. Def  Speed  Generation  Legendary
# 600       60     42           5      False
# 136       70     85           1      False
# 457       45     36           4      False

# %%
data.sort_values('Type 1', ascending=False).head(3)
# Out:
#        #      Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 371  339  Barboach  Water  Ground    288  50      48       43       46
# 97    90  Shellder  Water     NaN    305  30      65      100       45
# 240  222   Corsola  Water    Rock    380  55      55       85       65
#
#      Sp. Def  Speed  Generation  Legendary
# 371       41     60           3      False
# 97        25     40           1      False
# 240       85     35           2      False

# %%
data.sort_values(['Type 1', 'HP'], ascending=[1, 0]).head(3)
# Out:
#        #       Name Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 520  469    Yanmega    Bug    Flying    515  86      76       86      116
# 698  637  Volcarona    Bug      Fire    550  85      60       65      135
# 231  214  Heracross    Bug  Fighting    500  80     125       75       40
#
#      Sp. Def  Speed  Generation  Legendary
# 520       56     95           4      False
# 698      105    100           5      False
# 231       95     85           2      False

# %% [markdown]
# ## **11. Thay đổi thông tin bảng dữ liệu**

# %%
data.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
data = data.drop(columns=['Total'])
data.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
data['Total'] = data['Attack'] + data['Defense'] + data['HP']
data.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    143
# 1           1      False    185
# 2           1      False    245

# %% [markdown]
# ## **12. Sắp xếp lại thứ tự các cột**

# %%
data[['Name', 'Total', 'Attack', 'Speed']].head()
# Out:
#                     Name  Total  Attack  Speed
# 0              Bulbasaur    143      49     45
# 1                Ivysaur    185      62     60
# 2               Venusaur    245      82     80
# 3  VenusaurMega Venusaur    303     100     80
# 4             Charmander    134      52     65

# %%
cols = list(data.columns.values)
print(cols)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total']

# %%
data[cols[0:4] + [cols[-1]] + cols[4:-1]].head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    143  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    185  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    245  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %% [markdown]
# ## **13. Lưu bảng dữ liệu mới**

# %%
data.to_csv('modified.csv')

# %%
data.to_excel('modified.xlsx', index = False)

# %%
data.to_csv('modified_tab.csv', sep='\t')

# %% [markdown]
# ## **14. Tìm kiếm các sample thỏa mãn điều kiện (filtering)**

# %%
data.loc[(data['Type 1'] == 'Grass') & (data['Type 2'] == 'Poison')].head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    143
# 1           1      False    185
# 2           1      False    245

# %%
data.loc[(data['Type 1'] == 'Grass') | (data['Type 2'] == 'Poison')][0::10].loc[data['HP'] > 50].head(3)
# Out:
#        #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50    45  Vileplume  Grass  Poison  75      80       85      110       90
# 101   94     Gengar  Ghost  Poison  60      65       60      130       75
# 197  182  Bellossom  Grass     NaN  75      80       95       90      100
#
#      Speed  Generation  Legendary  Total
# 50      50           1      False    240
# 101    110           1      False    185
# 197     50           2      False    250

# %% [markdown]
# ## **15. Filtering bằng regex**

# %%
import re

# %%
data.loc[data['Name'].str.contains('Mega')].head(3)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 3      120     80           1      False    303
# 7       85    100           1      False    319
# 8      115    100           1      False    260

# %%
data.loc[data['Type 1'].str.contains('Fire|grass', regex=True)].head(3)
# Out:
#    #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 4  4  Charmander   Fire     NaN  39      52       43       60       50     65
# 5  5  Charmeleon   Fire     NaN  58      64       58       80       65     80
# 6  6   Charizard   Fire  Flying  78      84       78      109       85    100
#
#    Generation  Legendary  Total
# 4           1      False    134
# 5           1      False    180
# 6           1      False    240

# %%
data.loc[data['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)].head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    143
# 1           1      False    185
# 2           1      False    245

# %%
data.loc[data['Name'].str.contains('pi[a-z]*', flags=re.I, regex=True)].head(3)
# Out:
#      #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 13  10   Caterpie     Bug     NaN  45      30       35       20       20
# 20  16     Pidgey  Normal  Flying  40      45       40       35       35
# 21  17  Pidgeotto  Normal  Flying  63      60       55       50       50
#
#     Speed  Generation  Legendary  Total
# 13     45           1      False    110
# 20     56           1      False    125
# 21     71           1      False    178

# %%
data.loc[data['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)].head(3)
# Out:
#      #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  16     Pidgey  Normal  Flying  40      45       40       35       35
# 21  17  Pidgeotto  Normal  Flying  63      60       55       50       50
# 22  18    Pidgeot  Normal  Flying  83      80       75       70       70
#
#     Speed  Generation  Legendary  Total
# 20     56           1      False    125
# 21     71           1      False    178
# 22    101           1      False    238

# %%
data.loc[data['Name'].str.contains('^pi.*', flags=re.I, regex=True)].head(3)
# Out:
#      #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  16     Pidgey  Normal  Flying  40      45       40       35       35
# 21  17  Pidgeotto  Normal  Flying  63      60       55       50       50
# 22  18    Pidgeot  Normal  Flying  83      80       75       70       70
#
#     Speed  Generation  Legendary  Total
# 20     56           1      False    125
# 21     71           1      False    178
# 22    101           1      False    238

# %% [markdown]
# ## **16. Reset lại chỉ mục bảng dữ liệu**

# %%
new_data = data.loc[(data['Type 1'] == 'Grass') | (data['Type 2'] == 'Poison')][0::10].loc[data['HP'] > 50].head(3)
new_data
# Out:
#        #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50    45  Vileplume  Grass  Poison  75      80       85      110       90
# 101   94     Gengar  Ghost  Poison  60      65       60      130       75
# 197  182  Bellossom  Grass     NaN  75      80       95       90      100
#
#      Speed  Generation  Legendary  Total
# 50      50           1      False    240
# 101    110           1      False    185
# 197     50           2      False    250

# %%
new_data = new_data.reset_index()
new_data
# Out:
#    index    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0     50   45  Vileplume  Grass  Poison  75      80       85      110
# 1    101   94     Gengar  Ghost  Poison  60      65       60      130
# 2    197  182  Bellossom  Grass     NaN  75      80       95       90
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       90     50           1      False    240
# 1       75    110           1      False    185
# 2      100     50           2      False    250

# %%
new_data = new_data.reset_index(drop=True)
new_data
# Out:
#      #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   45  Vileplume  Grass  Poison  75      80       85      110       90
# 1   94     Gengar  Ghost  Poison  60      65       60      130       75
# 2  182  Bellossom  Grass     NaN  75      80       95       90      100
#
#    Speed  Generation  Legendary  Total
# 0     50           1      False    240
# 1    110           1      False    185
# 2     50           2      False    250

# %%
new_data.reset_index(drop=True, inplace = True)
new_data
# Out:
#      #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   45  Vileplume  Grass  Poison  75      80       85      110       90
# 1   94     Gengar  Ghost  Poison  60      65       60      130       75
# 2  182  Bellossom  Grass     NaN  75      80       95       90      100
#
#    Speed  Generation  Legendary  Total
# 0     50           1      False    240
# 1    110           1      False    185
# 2     50           2      False    250

# %% [markdown]
# ## **17. Groupby**

# %%
data.groupby(['Type 1']).mean().sort_values('Defense', ascending=False).head(10)
# Out:
# <ipython-input-53-90d84ee3bc80>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Type 1']).mean().sort_values('Defense', ascending=False).head(10)
#                  #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel   442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock    392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon  474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground  356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost   486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water   303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice     423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# ...

# %%
data.groupby(['Type 1', 'Type 2']).count()
# Out:
#                   #  Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Electric   2     2   2       2        2        2        2      2
#        Fighting   2     2   2       2        2        2        2      2
#        Fire       2     2   2       2        2        2        2      2
#        Flying    14    14  14      14       14       14       14     14
#        Ghost      1     1   1       1        1        1        1      1
# ...              ..   ...  ..     ...      ...      ...      ...    ...
# Water  Ice        3     3   3       3        3        3        3      3
#        Poison     3     3   3       3        3        3        3      3
#        Psychic    5     5   5       5        5        5        5      5
#        Rock       4     4   4       4        4        4        4      4
#        Steel      1     1   1       1        1        1        1      1
#
#                  Generation  Legendary  Total
# Type 1 Type 2
# ...

# %%
df = data.groupby(['Type 1'])['Attack', 'Defense'].apply(lambda x: np.sum(x)/len(x))
df.head(3)
# Out:
# <ipython-input-77-dcc0a50d3102>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df = data.groupby(['Type 1'])['Attack', 'Defense'].apply(lambda x: np.sum(x)/len(x))
#             Attack    Defense
# Type 1
# Bug      70.971014  70.724638
# Dark     88.387097  70.225806
# Dragon  112.125000  86.375000

# %%
df = data.groupby(['Type 1']).agg({'Attack': 'mean',
                                   'Defense': 'sum',
                                   'Speed': lambda x: len(x)})
df.head(3)
# Out:
#             Attack  Defense  Speed
# Type 1
# Bug      70.971014     4880     69
# Dark     88.387097     2177     31
# Dragon  112.125000     2764     32

# %% [markdown]
# ## **Quiz**

# %%
# 1
df = pd.read_csv('/content/Pokemon.csv')

# %%
# 2
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# 3
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
# 4
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# 5
sr = df.iloc[10:16]
sr
# Out:
#      #                     Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 10   8                Wartortle  Water     NaN    405  59      63       80
# 11   9                Blastoise  Water     NaN    530  79      83      100
# 12   9  BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 13  10                 Caterpie    Bug     NaN    195  45      30       35
# 14  11                  Metapod    Bug     NaN    205  50      20       55
# 15  12               Butterfree    Bug  Flying    395  60      45       50
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 10       65       80     58           1      False
# 11       85      105     78           1      False
# 12      135      115     78           1      False
# 13       20       20     45           1      False
# 14       25       25     30           1      False
# 15       90       80     70           1      False

# %%
# 6
sr = df.iloc[50]
sr
# Out:
# #                    45
# Name          Vileplume
# Type 1            Grass
# Type 2           Poison
# Total               490
# HP                   75
# Attack               80
# Defense              85
# Sp. Atk             110
# Sp. Def              90
# Speed                50
# Generation            1
# Legendary         False
# Name: 50, dtype: object

# %%
# 7
grass_pokemon = df[df['Type 1'] == 'Grass']
grass_pokemon
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 48    43                 Oddish  Grass    Poison    320   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    313   56      61       65
# 719  651              Quilladin  Grass       NaN    405   61      78       95
# 720  652             Chesnaught  Grass  Fighting    530   88     107      122
# 740  672                 Skiddo  Grass       NaN    350   66      65       48
# 741  673                 Gogoat  Grass       NaN    531  123     100       62
#
# ...

# %%
# 8
high_hp_pokemon = df[df['HP'] > 100]
high_hp_pokemon
# Out:
#        #              Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 44    39        Jigglypuff  Normal   Fairy    270  115      45       20
# 45    40        Wigglytuff  Normal   Fairy    435  140      70       45
# 96    89               Muk  Poison     NaN    500  105     105       75
# 120  112            Rhydon  Ground    Rock    485  105     130      120
# 121  113           Chansey  Normal     NaN    450  250       5        5
# ..   ...               ...     ...     ...    ...  ...     ...      ...
# 753  683        Aromatisse   Fairy     NaN    462  101      72       72
# 769  699           Aurorus    Rock     Ice    521  123      77       72
# 792  716           Xerneas   Fairy     NaN    680  126     131       95
# 793  717           Yveltal    Dark  Flying    680  126     131       95
# 794  718  Zygarde50% Forme  Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# 9
chu_pokemon = df[df['Name'].str.contains('chu', case=False)]
chu_pokemon
# Out:
#        #      Name    Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 30    25   Pikachu  Electric      NaN    320  35      55       40       50
# 31    26    Raichu  Electric      NaN    485  60      90       55       90
# 186  172     Pichu  Electric      NaN    205  20      40       15       35
# 257  238  Smoochum       Ice  Psychic    305  45      30       15       85
#
#      Sp. Def  Speed  Generation  Legendary
# 30        50     90           1      False
# 31        80    110           1      False
# 186       35     60           2      False
# 257       65     65           2      False

# %%
# 10
sorted_df = df.sort_values(by='Attack', ascending=False)
sorted_df
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# ..   ...                      ...      ...       ...    ...  ...     ...
# 139  129                 Magikarp    Water       NaN    200   20      10
# 261  242                  Blissey   Normal       NaN    540  255      10
# 230  213                  Shuckle      Bug      Rock    505   20      10
# 121  113                  Chansey   Normal       NaN    450  250       5
# 488  440                  Happiny   Normal       NaN    220  100       5
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# 11
df_reset = sorted_df.reset_index(drop=True)
df_reset
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 0    150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 1    214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 2    383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 3    384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 4    386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# ..   ...                      ...      ...       ...    ...  ...     ...
# 795  129                 Magikarp    Water       NaN    200   20      10
# 796  242                  Blissey   Normal       NaN    540  255      10
# 797  213                  Shuckle      Bug      Rock    505   20      10
# 798  113                  Chansey   Normal       NaN    450  250       5
# 799  440                  Happiny   Normal       NaN    220  100       5
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# 12
selected_columns = df[['Name', 'Type 1', 'HP']]
selected_columns
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
# 13
grass_poison_pokemon = df[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
grass_poison_pokemon
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 75    69             Bellsprout  Grass  Poison    300   50      75       35
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 344  315                Roselia  Grass  Poison    400   50      60       45
# ...

# %%
# 14
legendary_hp_mean = df[df['Legendary'] == True]['HP'].mean()
legendary_hp_mean
# Out:
# 92.73846153846154

# %%
# 15
even_index_rows = df[df.index % 2 == 0]
even_index_rows
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur    Grass  Poison    318   45      49
# 2      3                   Venusaur    Grass  Poison    525   80      82
# 4      4                 Charmander     Fire     NaN    309   39      52
# 6      6                  Charizard     Fire  Flying    534   78      84
# 8      6  CharizardMega Charizard Y     Fire  Flying    634   78     104
# ..   ...                        ...      ...     ...    ...  ...     ...
# 790  714                     Noibat   Flying  Dragon    245   40      30
# 792  716                    Xerneas    Fairy     NaN    680  126     131
# 794  718           Zygarde50% Forme   Dragon  Ground    600  108     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700   50     160
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680   80     160
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# 16
even_index_rows.to_csv("filtered_pokemon.csv", index=False)

# %%
# 17
selected_rows_and_columns = df.loc[:9, ['Name', 'Type 1', 'Attack']]
selected_rows_and_columns
# Out:
#                         Name Type 1  Attack
# 0                  Bulbasaur  Grass      49
# 1                    Ivysaur  Grass      62
# 2                   Venusaur  Grass      82
# 3      VenusaurMega Venusaur  Grass     100
# 4                 Charmander   Fire      52
# 5                 Charmeleon   Fire      64
# 6                  Charizard   Fire      84
# 7  CharizardMega Charizard X   Fire     130
# 8  CharizardMega Charizard Y   Fire     104
# 9                   Squirtle  Water      48

# %%
# 18
max_defense = df['Defense'].max()
max_defense
# Out:
# 230

# %%
# 19
above_mean_speed = df[df['Speed'] > df['Speed'].mean()]
above_mean_speed
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 2      3                   Venusaur    Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur    Grass  Poison    625   80     100
# 5      5                 Charmeleon     Fire     NaN    405   58      64
# 6      6                  Charizard     Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# ..   ...                        ...      ...     ...    ...  ...     ...
# 794  718           Zygarde50% Forme   Dragon  Ground    600  108     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700   50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600   80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680   80     160
# 799  721                  Volcanion     Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# 20
selected_rows_and_columns = df.loc[:2, ['Name', 'Attack']]
selected_rows_and_columns
# Out:
#         Name  Attack
# 0  Bulbasaur      49
# 1    Ivysaur      62
# 2   Venusaur      82

# %%
# 21
type_counts = df['Type 1'].value_counts()
type_counts
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
# 22
gen_3_or_5_pokemon = df[(df['Generation'] == 3) | (df['Generation'] == 5)]
gen_3_or_5_pokemon
# Out:
#        #                     Name  Type 1    Type 2  Total   HP  Attack  \
# 272  252                  Treecko   Grass       NaN    310   40      45
# 273  253                  Grovyle   Grass       NaN    405   50      65
# 274  254                 Sceptile   Grass       NaN    530   70      85
# 275  254    SceptileMega Sceptile   Grass    Dragon    630   70     110
# 276  255                  Torchic    Fire       NaN    310   45      60
# ..   ...                      ...     ...       ...    ...  ...     ...
# 713  647     KeldeoOrdinary Forme   Water  Fighting    580   91      72
# 714  647     KeldeoResolute Forme   Water  Fighting    580   91      72
# 715  648       MeloettaAria Forme  Normal   Psychic    600  100      77
# 716  648  MeloettaPirouette Forme  Normal  Fighting    600  100     128
# 717  649                 Genesect     Bug     Steel    600   71     120
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# 23
df.loc[df['Type 1']=='Fire', 'Type 1'] = 'Flame'
df.loc[df['Type 1']=='Flame'].head()
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4  4                 Charmander  Flame     NaN    309  39      52       43
# 5  5                 Charmeleon  Flame     NaN    405  58      64       58
# 6  6                  Charizard  Flame  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X  Flame  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y  Flame  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
df.loc[df['Type 1']=='Flame', 'Type 1'] = 'Fire'

# %%
# 24
p_starting_names = df[df['Name'].str.startswith('P')]
p_starting_names.head()
# Out:
#      #                 Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 20  16               Pidgey    Normal  Flying    251  40      45       40
# 21  17            Pidgeotto    Normal  Flying    349  63      60       55
# 22  18              Pidgeot    Normal  Flying    479  83      80       75
# 23  18  PidgeotMega Pidgeot    Normal  Flying    579  83      80       80
# 30  25              Pikachu  Electric     NaN    320  35      55       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20       35       35     56           1      False
# 21       50       50     71           1      False
# 22       70       70    101           1      False
# 23      135       80    121           1      False
# 30       50       50     90           1      False

# %%
# 25
type_attack_mean = df.groupby('Type 1')['Attack'].mean()
type_attack_mean
# Out:
# Type 1
# Bug          70.971014
# Dark         88.387097
# Dragon      112.125000
# Electric     69.090909
# Fairy        61.529412
# Fighting     96.777778
# Fire         84.769231
# Flying       78.750000
# Ghost        73.781250
# Grass        73.214286
# Ground       95.750000
# Ice          72.750000
# Normal       73.469388
# Poison       74.678571
# Psychic      71.456140
# Rock         92.863636
# Steel        92.703704
# Water        74.151786
# Name: Attack, dtype: float64

# %%
# 26
sorted_df = df.sort_values(by=['Type 1', 'Attack'], ascending=[True, False])
sorted_df
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 137  127        PinsirMega Pinsir    Bug    Flying    600  65     155
# 19    15    BeedrillMega Beedrill    Bug    Poison    495  65     150
# 229  212        ScizorMega Scizor    Bug     Steel    600  70     150
# 650  589               Escavalier    Bug     Steel    495  70     135
# ..   ...                      ...    ...       ...    ...  ..     ...
# 405  370                  Luvdisc  Water       NaN    330  43      30
# 198  183                   Marill  Water     Fairy    250  70      20
# 508  458                  Mantyke  Water    Flying    345  45      20
# 381  349                   Feebas  Water       NaN    200  20      15
# 139  129                 Magikarp  Water       NaN    200  20      10
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 232      115       40      105     75           2      False
# ...

# %%
# 27
type_defense_median = df.groupby('Type 1')['Defense'].median()
type_defense_median
# Out:
# Type 1
# Bug          60.0
# Dark         70.0
# Dragon       90.0
# Electric     65.0
# Fairy        66.0
# Fighting     70.0
# Fire         64.0
# Flying       75.0
# Ghost        72.5
# Grass        66.0
# Ground       84.5
# Ice          75.0
# Normal       60.0
# Poison       67.0
# Psychic      65.0
# Rock        100.0
# Steel       120.0
# Water        70.0
# Name: Defense, dtype: float64

# %%
# 28
legendary_high_attack = df[(df['Legendary'] == True) & (df['Attack'] > 100)]
legendary_high_attack.head()
# Out:
#        #                 Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 162  150               Mewtwo  Psychic       NaN    680  106     110       90
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 164  150  MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
# 263  244                Entei     Fire       NaN    580  115     115       85
# 270  250                Ho-oh     Fire    Flying    680  106     130       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 162      154       90    130           1       True
# 163      154      100    130           1       True
# 164      194      120    140           1       True
# 263       90       75    100           2       True
# 270      110      154     90           2       True

# %%
# 29
selected_columns_renamed = df.loc[:, ['Name', 'Total']].rename(columns={'Total': 'Overall'})
selected_columns_renamed
# Out:
#                       Name  Overall
# 0                Bulbasaur      318
# 1                  Ivysaur      405
# 2                 Venusaur      525
# 3    VenusaurMega Venusaur      625
# 4               Charmander      309
# ..                     ...      ...
# 795                Diancie      600
# 796    DiancieMega Diancie      700
# 797    HoopaHoopa Confined      600
# 798     HoopaHoopa Unbound      680
# 799              Volcanion      600
#
# [800 rows x 2 columns]

# %%
# 30
strong_water_pokemon = df[(df['Type 1'] == 'Water') & (df['Attack'] >= 80)]
strong_water_pokemon.head()
# Out:
#      #                     Name Type 1    Type 2  Total  HP  Attack  Defense  \
# 11   9                Blastoise  Water       NaN    530  79      83      100
# 12   9  BlastoiseMega Blastoise  Water       NaN    630  79     103      120
# 60  55                  Golduck  Water       NaN    500  80      82       78
# 67  62                Poliwrath  Water  Fighting    510  90      95       95
# 98  91                 Cloyster  Water       Ice    525  50      95      180
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 11       85      105     78           1      False
# 12      135      115     78           1      False
# 60       95       80     85           1      False
# 67       70       90     70           1      False
# 98       85       45     70           1      False

# %%
# 31
gen_4_defense = df[df['Generation'] == 4][['Name', 'Defense']]
gen_4_defense
# Out:
#                   Name  Defense
# 432            Turtwig       64
# 433             Grotle       85
# 434           Torterra      105
# 435           Chimchar       44
# 436           Monferno       52
# ..                 ...      ...
# 548            Manaphy      100
# 549            Darkrai       90
# 550  ShayminLand Forme      100
# 551   ShayminSky Forme       75
# 552             Arceus      120
#
# [121 rows x 2 columns]

# %%
# 32
type_combination_mean = df.groupby(['Type 1', 'Type 2'])['Total'].mean()
type_combination_mean
# Out:
# Type 1  Type 2
# Bug     Electric    395.500000
#         Fighting    550.000000
#         Fire        455.000000
#         Flying      419.500000
#         Ghost       236.000000
#                        ...
# Water   Ice         511.666667
#         Poison      426.666667
#         Psychic     481.000000
#         Rock        428.750000
#         Steel       530.000000
# Name: Total, Length: 136, dtype: float64

# %%
# 33
mid_total_pokemon = df[(df['Total'] >= 400) & (df['Total'] <= 500)]
mid_total_pokemon
# Out:
#        #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 1      2                Ivysaur   Grass  Poison    405  60      62       63
# 5      5             Charmeleon    Fire     NaN    405  58      64       58
# 10     8              Wartortle   Water     NaN    405  59      63       80
# 19    15  BeedrillMega Beedrill     Bug  Poison    495  65     150       40
# 22    18                Pidgeot  Normal  Flying    479  83      80       75
# ..   ...                    ...     ...     ...    ...  ..     ...      ...
# 779  709              Trevenant   Ghost   Grass    474  85     110       76
# 784  711  GourgeistAverage Size   Ghost   Grass    494  65      90      122
# 785  711    GourgeistSmall Size   Ghost   Grass    494  55      85      122
# 786  711    GourgeistLarge Size   Ghost   Grass    494  75      95      122
# 787  711    GourgeistSuper Size   Ghost   Grass    494  85     100      122
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
