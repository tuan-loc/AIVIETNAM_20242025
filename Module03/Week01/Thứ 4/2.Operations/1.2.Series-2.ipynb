# %%
import pandas as pd
import numpy as np

data = pd.Series(['C++', 'Golang', 'Java', 'Python', 'Swift'], 
                 index=list('CGJPS'), 
                 name='Programming Language')
data
# Out:
# C       C++
# G    Golang
# J      Java
# P    Python
# S     Swift
# Name: Programming Language, dtype: object

# %%
data['K'] = "Kotlin"
data
# Out:
# C       C++
# G    Golang
# J      Java
# P    Python
# S     Swift
# K    Kotlin
# Name: Programming Language, dtype: object

# %%
data = data.sort_index(inplace=False)

# %%
data
# Out:
# C       C++
# G    Golang
# J      Java
# K    Kotlin
# P    Python
# S     Swift
# Name: Programming Language, dtype: object

# %%
data = data.drop('P')

# %%
data
# Out:
# C       C++
# G    Golang
# J      Java
# S     Swift
# Name: Programming Language, dtype: object

# %%
data.drop('P')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data.drop('P')
#
# File E:\SoftInstallation\conda\envs\tf_env\Lib\site-packages\pandas\core\series.py:5085, in Series.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4988 def drop(
#    4989     self,
#    4990     labels: IndexLabel = None,
#    (...)
#    4997     errors: IgnoreRaise = "raise",
#    4998 ) -> Series | None:
#    4999     """
#    5000     Return Series with specified index labels removed.
#    5001
#    (...)
#    5083     dtype: float64
#    5084     """
# -> 5085     return super().drop(
#    5086         labels=labels,
#    5087         axis=axis,
#    5088         index=index,
#    5089         columns=columns,
#    5090         level=level,
#    5091         inplace=inplace,
#    5092         errors=errors,
#    5093     )
#
# File E:\SoftInstallation\conda\envs\tf_env\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File E:\SoftInstallation\conda\envs\tf_env\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File E:\SoftInstallation\conda\envs\tf_env\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['P'] not found in axis"

# %%
()

# %%
data[['C', 'J']]

# %%
data2 = pd.Series(['C++', 'Golang', 'Java', 'Python', 'Swift'], 
                 index=list('CGJPC'), 
                 name='Programming Language')
data2

# %%
data2['C']

# %%
data.index

# %%
data.name

# %%
data.values

# %%
data['C':'P']

# %%
data[['C', 'P']]

# %%
result = data[2:4]
result

# %% [markdown]
# ## Drop rows

# %%
# drop
data.drop('C')

# %%
data.drop(['C', 'P'])

# %% [markdown]
# ## Insert rows

# %%
data

# %%
data['K'] = 'Kotlin'
data

# %%
data2 = data.sort_index(inplace=True)
print(data2)

# %% [markdown]
# ## string

# %%
data

# %%
data.str.count('Java')

# %%
data.str.count('a')

# %%
data.str.upper()

# %%
data.replace('Java', 'C#')

# %% [markdown]
# ## Missing values

# %%
import pandas as pd
import numpy as np

data = pd.Series([1, 6, 3, 8, np.nan, 7, np.nan, 2], name='num_dropped')
data

# %%
data.dropna()

# %%
data.fillna(1.0)

# %%
data.interpolate()

# %%
# Most Pandas functions happily ignore the missing values

data.sum()

# %%
data.min()

# %%
data.max()

# %%
data.mean()

# %%
data.std()

# %%
data.idxmax()

# %%
data.argmax()

# %%
import pandas as pd
import numpy as np

center1 = pd.Series([12, 23, 31, 11, 9], 
                    index=list(['C++', 'Golang', 'Java', 'Python', 'Swift']), 
                    name='num_registered')
center1

# %%
center2 = pd.Series([42, 18, 44, 49, 27], 
                    index=list(['C++', 'Golang', 'Java', 'Python', 'Swift']), 
                    name='num_registered')
center2

# %%
total = center1 + center2
total

# %%
center1 = pd.Series([12, 23, 31, 11, 9], 
                    index=list(['C++', 'Golang', 'Java', 'Python', 'Swift']), 
                    name='num_registered')
center2 = pd.Series([42, 44, 49, 27], 
                    index=list(['Golang', 'Java', 'Python', 'Swift']), 
                    name='num_registered')
total = center1 + center2
total

# %% [markdown]
# ## Comparison

# %%
np.array_equal(data1.values, data2.values, equal_nan=True)

# %%
np.array_equal(data1.values, data1.values, equal_nan=True)

# %% [markdown]
# ## update series

# %%
import pandas as pd
import numpy as np

data = pd.Series(['C++', 'Golang', 'Java', 'Python', 'Swift'], name='language')
data

# %%
data[2.5] = 'C#'
data

# %%
data.sort_index(inplace=True)

# %%
data

# %%
data.reset_index(drop=True)
