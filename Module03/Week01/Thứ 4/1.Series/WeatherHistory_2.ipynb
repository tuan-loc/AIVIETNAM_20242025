# %%
import numpy as np
import pandas as pd

df = pd.read_csv('weatherHistory_v2.csv')

data_series = pd.Series(data=df.iloc[:,0])
data_series.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 51962 entries, 0 to 51961
# Series name: Temperature (C)
# Non-Null Count  Dtype
# --------------  -----
# 51962 non-null  float64
# dtypes: float64(1)
# memory usage: 406.1 KB

# %%
print(data_series.size)
print(data_series.dtypes)
print(data_series.shape)
# Out:
# 51962
# float64
# (51962,)

# %%
data_series.describe()
# Out:
# count    51962.000000
# mean        14.054318
# std          8.361805
# min          0.005556
# 25%          7.222222
# 50%         13.705556
# 75%         20.000000
# max         39.588889
# Name: Temperature (C), dtype: float64

# %%
data_series.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data_series.hist()
# Out:
# <Axes: >

# %%
data_series.plot.box()
# Out:
# <Axes: >
