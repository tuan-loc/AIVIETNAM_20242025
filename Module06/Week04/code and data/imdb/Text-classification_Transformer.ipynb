# %%
# %pip install datasets nltk
# %pip install torchtext
# %pip install -U portalocker>=2.0.0
# Out:
# Requirement already satisfied: datasets in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (2.15.0)
# Requirement already satisfied: nltk in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: numpy>=1.17 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (1.24.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (14.0.1)
# Requirement already satisfied: pyarrow-hotfix in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (0.5)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (2.1.3)
# Requirement already satisfied: requests>=2.19.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (3.9.0)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: click in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: filelock in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from huggingface-hub>=0.18.0->datasets) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from huggingface-hub>=0.18.0->datasets) (4.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchtext in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (0.16.1)
# Requirement already satisfied: tqdm in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torchtext) (4.66.1)
# Requirement already satisfied: requests in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torchtext) (2.31.0)
# Requirement already satisfied: torch==2.1.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torchtext) (2.1.1)
# Requirement already satisfied: numpy in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torchtext) (1.24.1)
# Requirement already satisfied: torchdata==0.7.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torchtext) (0.7.1)
# Requirement already satisfied: filelock in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (3.9.0)
# Requirement already satisfied: typing-extensions in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (4.4.0)
# Requirement already satisfied: sympy in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (1.12)
# Requirement already satisfied: networkx in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (3.0)
# Requirement already satisfied: jinja2 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (3.1.2)
# Requirement already satisfied: fsspec in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torch==2.1.1->torchtext) (2.1.0)
# Requirement already satisfied: urllib3>=1.25 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from torchdata==0.7.1->torchtext) (1.26.13)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.1->torchtext) (12.3.101)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from requests->torchtext) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from requests->torchtext) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from requests->torchtext) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from jinja2->torch==2.1.1->torchtext) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/s12gb1/pytorchenv/lib/python3.10/site-packages (from sympy->torch==2.1.1->torchtext) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import nltk
nltk.download('punkt')

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [nltk_data] Downloading package punkt to /home/s12gb1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # 1. Data preparation

# %%
from datasets import load_dataset

imdb = load_dataset("imdb")
train_data, test_data = imdb['train'], imdb['test']

# %%
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator


tokenizer = get_tokenizer("basic_english")
vocab_size = 20000

def yield_tokens(data_iter):
    for data in data_iter:
        yield tokenizer(data["text"])

vocab = build_vocab_from_iterator(yield_tokens(train_data),
                                  min_freq = 3,
                                  max_tokens=vocab_size,
                                  specials=["<pad>", "<s>", "<unk>"])
vocab.set_default_index(vocab["<unk>"])

# %%
seq_length = 200
text_pipeline = lambda x: vocab(tokenizer(x))

def collate_batch(batch, seq_length=seq_length):
    text_list, label_list = [], []
    for sample in batch:
        label_list.append(sample['label'])

        text_processed = text_pipeline(sample['text'])[:seq_length]
        if len(text_processed) < seq_length:
            pad_size = seq_length - len(text_processed) -1
            text_processed = [vocab["<pad>"]] * pad_size + [vocab["<s>"]] + text_processed
        text_list.append(text_processed)

    input_ids = torch.tensor(text_list, dtype=torch.int64)
    labels = torch.tensor(label_list, dtype=torch.int64)
    return (input_ids, labels)

# %%
from torch.utils.data import DataLoader
batch_size = 32

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, collate_fn=collate_batch, drop_last=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False, collate_fn=collate_batch, drop_last=True)

# %% [markdown]
# # 2. Model

# %%
class TransformerBlock(nn.Module):
    def __init__(self, embed_dim, num_heads, ff_dim, dropout):
        super().__init__()
        self.attn = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=num_heads, dropout=0.0, bias=True)
        self.ffn = nn.Sequential(
            nn.Linear(in_features=embed_dim, out_features=ff_dim, bias=True),
            nn.ReLU(),
            nn.Linear(in_features=ff_dim, out_features=embed_dim, bias=True)
        )
        self.layernorm_1 = nn.LayerNorm(normalized_shape=embed_dim, eps=1e-6)
        self.layernorm_2 = nn.LayerNorm(normalized_shape=embed_dim, eps=1e-6)
        self.dropout_1 = nn.Dropout(p=dropout)
        self.dropout_2 = nn.Dropout(p=dropout)

    def forward(self, query, key, value):
        attn_output, _ = self.attn(query, key, value)
        attn_output = self.dropout_1(attn_output)
        out_1 = self.layernorm_1(query + attn_output)
        ffn_output = self.ffn(out_1)
        ffn_output = self.dropout_2(ffn_output)
        out_2 = self.layernorm_2(out_1 + ffn_output)
        return out_2


class TokenAndPositionEmbedding(nn.Module):
    def __init__(self, vocab_size, embed_dim, max_length, device):
        super().__init__()
        self.device = device
        self.word_emb = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embed_dim)
        self.pos_emb = nn.Embedding(num_embeddings=max_length, embedding_dim=embed_dim)

    def forward(self, x):
        N, seq_len = x.size()
        positions = torch.arange(0, seq_len).expand(N, seq_len).to(self.device)
        output1 = self.word_emb(x)
        output2 = self.pos_emb(positions)
        output = output1 + output2
        return output


class TransformerTextCls(nn.Module):
    def __init__(self, vocab_size, max_length, embed_dim, num_heads, ff_dim, dropout, device):
        super().__init__()
        self.embd_layer = TokenAndPositionEmbedding(vocab_size, embed_dim, max_length, device)
        self.transformer_layer = TransformerBlock(embed_dim, num_heads, ff_dim, dropout)
        self.pooling = nn.AvgPool1d(kernel_size=max_length)
        self.fc1 = nn.Linear(in_features=embed_dim, out_features=20)
        self.fc2 = nn.Linear(in_features=20, out_features=2)
        self.dropout = nn.Dropout(p=dropout)
        self.relu = nn.ReLU()
    def forward(self, x):
        output = self.embd_layer(x)
        output = self.transformer_layer(output, output, output)
        output = self.pooling(output.permute(0,2,1)).squeeze()
        output = self.dropout(output)
        output = self.fc1(output)
        output = self.dropout(output)
        output = self.fc2(output)
        return output

# %%
max_length = seq_length #200
embed_dim = 32
num_heads = 2
ff_dim = 32
dropout = 0.1
model = TransformerTextCls(vocab_size, max_length, embed_dim, num_heads, ff_dim, dropout, device)

# %% [markdown]
# # 3. Evaluate

# %%
def evaluate(model, test_loader, criterion, device):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)
            test_loss += loss.item()
            correct +=(predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    accuracy = 100* correct / total

    return test_loss, accuracy

# %% [markdown]
# # 4. Train

# %%
max_epoch = 20
LR = 0.001
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# %%
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

model.to(device)
for epoch in range(max_epoch):
    model.train()
    running_loss = 0.0
    running_correct = 0
    total = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()

        loss.backward()
        optimizer.step()

    epoch_loss =  running_loss / len(train_loader)
    epoch_accuracy = 100* running_correct / total
    test_loss, test_accuracy = evaluate(model, test_loader, criterion, device)

    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
# Out:
# Epoch [1/20], Loss: 0.6222, Accuracy: 63.90%, Test Loss: 0.5838, Test Accuracy: 69.64%
# Epoch [2/20], Loss: 0.4577, Accuracy: 78.89%, Test Loss: 0.5406, Test Accuracy: 73.96%
# Epoch [3/20], Loss: 0.3752, Accuracy: 83.40%, Test Loss: 0.5606, Test Accuracy: 74.43%
# Epoch [4/20], Loss: 0.3177, Accuracy: 86.52%, Test Loss: 0.5977, Test Accuracy: 74.21%
# Epoch [5/20], Loss: 0.2831, Accuracy: 88.18%, Test Loss: 0.4702, Test Accuracy: 79.52%
# Epoch [6/20], Loss: 0.2457, Accuracy: 90.10%, Test Loss: 0.4479, Test Accuracy: 81.43%
# Epoch [7/20], Loss: 0.2144, Accuracy: 91.55%, Test Loss: 0.5282, Test Accuracy: 79.05%
# Epoch [8/20], Loss: 0.1926, Accuracy: 92.32%, Test Loss: 0.5762, Test Accuracy: 78.51%
# Epoch [9/20], Loss: 0.1719, Accuracy: 93.45%, Test Loss: 0.5141, Test Accuracy: 81.45%
# Epoch [10/20], Loss: 0.1550, Accuracy: 94.02%, Test Loss: 0.6025, Test Accuracy: 78.81%
# Epoch [11/20], Loss: 0.1343, Accuracy: 94.95%, Test Loss: 0.6016, Test Accuracy: 80.75%
# Epoch [12/20], Loss: 0.1220, Accuracy: 95.49%, Test Loss: 0.7585, Test Accuracy: 78.21%
# Epoch [13/20], Loss: 0.1078, Accuracy: 95.89%, Test Loss: 0.7036, Test Accuracy: 81.03%
# Epoch [14/20], Loss: 0.0997, Accuracy: 96.29%, Test Loss: 0.7592, Test Accuracy: 80.14%
# Epoch [15/20], Loss: 0.0866, Accuracy: 96.82%, Test Loss: 0.7315, Test Accuracy: 81.23%
# Epoch [16/20], Loss: 0.0783, Accuracy: 97.12%, Test Loss: 0.8174, Test Accuracy: 80.16%
# Epoch [17/20], Loss: 0.0638, Accuracy: 97.74%, Test Loss: 0.8956, Test Accuracy: 80.62%
# Epoch [18/20], Loss: 0.0657, Accuracy: 97.54%, Test Loss: 0.9360, Test Accuracy: 80.35%
# Epoch [19/20], Loss: 0.0521, Accuracy: 98.12%, Test Loss: 1.0345, Test Accuracy: 80.23%
# Epoch [20/20], Loss: 0.0603, Accuracy: 97.78%, Test Loss: 0.9792, Test Accuracy: 80.69%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(test_accuracies, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),100])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Binary Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
