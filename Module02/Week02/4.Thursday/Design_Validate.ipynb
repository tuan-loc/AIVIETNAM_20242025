# %% [markdown]
# # Download dataset

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1SNycaoKRUhUVGzhd_6f_VJRiS8xQqZoR/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1SNycaoKRUhUVGzhd_6f_VJRiS8xQqZoR
# To: /content/train.csv
# 100% 2.76M/2.76M [00:00<00:00, 37.0MB/s]

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit

from numpy import percentile

# %% [markdown]
# # Read data

# %%
df_train = pd.read_csv("./train.csv")

# %%
df_train
# Out:
#           id  Area           Location  No. of Bedrooms  Resale  \
# 0      26813   964  Hooghly Chinsurah                3       0
# 1      10365  1075         Virar West                2       1
# 2      17863  2092          Manikonda                3       0
# 3      24337  1174        Devanahalli                2       1
# 4      12590  1380           Kharghar                2       1
# ...      ...   ...                ...              ...     ...
# 26365  16850  1060              Powai                2       1
# 26366   6265  1250             Jasola                3       1
# 26367  11284   440     Mira Road East                1       0
# 26368    860   875         Medavakkam                2       0
# 26369  15795  1080        Mulund West                3       0
#
#        MaintenanceStaff  Gymnasium  SwimmingPool  LandscapedGardens  \
# 0                     9          9             9                  9
# 1                     1          1             0                  0
# 2                     1          1             1                  1
# 3                     9          9             9                  9
# 4                     9          9             9                  9
# ...                 ...        ...           ...                ...
# 26365                 9          9             9                  9
# 26366                 0          0             0                  0
# 26367                 0          0             0                  1
# 26368                 0          1             1                  0
# 26369                 9          9             9                  9
#
#        JoggingTrack  ...  BED  VaastuCompliant  Microwave  GolfCourse  TV  \
# 0                 9  ...    9                9          9           9   9
# 1                 0  ...    1                0          0           0   0
# 2                 0  ...    0                1          0           0   0
# 3                 9  ...    9                9          9           9   9
# 4                 9  ...    9                9          9           9   9
# ...             ...  ...  ...              ...        ...         ...  ..
# 26365             9  ...    9                9          9           9   9
# 26366             0  ...    0                0          1           0   0
# 26367             0  ...    0                0          0           0   0
# 26368             1  ...    0                0          0           0   0
# 26369             9  ...    9                9          9           9   9
#
#        DiningTable  Sofa  Wardrobe  Refrigerator     Price
# 0                9     9         9             9   7500000
# 1                0     0         0             0   6200000
# 2                0     0         0             0  10400000
# 3                9     9         9             9  18600000
# 4                9     9         9             9   9500000
# ...            ...   ...       ...           ...       ...
# 26365            9     9         9             9   2400000
# 26366            0     0         0             0  18900000
# 26367            0     0         0             0   3700000
# 26368            0     0         0             0   4790000
# 26369            9     9         9             9   6000000
#
# [26370 rows x 41 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26370 entries, 0 to 26369
# Data columns (total 41 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   26370 non-null  int64
#  1   Area                 26370 non-null  int64
#  2   Location             26370 non-null  object
#  3   No. of Bedrooms      26370 non-null  int64
#  4   Resale               26370 non-null  int64
#  5   MaintenanceStaff     26370 non-null  int64
#  6   Gymnasium            26370 non-null  int64
#  7   SwimmingPool         26370 non-null  int64
#  8   LandscapedGardens    26370 non-null  int64
#  9   JoggingTrack         26370 non-null  int64
#  10  RainWaterHarvesting  26370 non-null  int64
#  11  IndoorGames          26370 non-null  int64
#  12  ShoppingMall         26370 non-null  int64
#  13  Intercom             26370 non-null  int64
#  14  SportsFacility       26370 non-null  int64
#  15  ATM                  26370 non-null  int64
#  16  ClubHouse            26370 non-null  int64
#  17  School               26370 non-null  int64
#  18  24X7Security         26370 non-null  int64
#  19  PowerBackup          26370 non-null  int64
#  20  CarParking           26370 non-null  int64
#  21  StaffQuarter         26370 non-null  int64
#  22  Cafeteria            26370 non-null  int64
#  23  MultipurposeRoom     26370 non-null  int64
#  24  Hospital             26370 non-null  int64
#  25  WashingMachine       26370 non-null  int64
#  26  Gasconnection        26370 non-null  int64
#  27  AC                   26370 non-null  int64
#  28  Wifi                 26370 non-null  int64
#  29  Children'splayarea   26370 non-null  int64
#  30  LiftAvailable        26370 non-null  int64
#  31  BED                  26370 non-null  int64
#  32  VaastuCompliant      26370 non-null  int64
#  33  Microwave            26370 non-null  int64
#  34  GolfCourse           26370 non-null  int64
#  35  TV                   26370 non-null  int64
#  36  DiningTable          26370 non-null  int64
#  37  Sofa                 26370 non-null  int64
#  38  Wardrobe             26370 non-null  int64
#  39  Refrigerator         26370 non-null  int64
#  40  Price                26370 non-null  int64
# dtypes: int64(40), object(1)
# memory usage: 8.2+ MB

# %%
df_train.nunique()
# Out:
# id                     26370
# Area                    2326
# Location                1640
# No. of Bedrooms            9
# Resale                     2
# MaintenanceStaff           3
# Gymnasium                  3
# SwimmingPool               3
# LandscapedGardens          3
# JoggingTrack               3
# RainWaterHarvesting        3
# IndoorGames                3
# ShoppingMall               3
# Intercom                   3
# SportsFacility             3
# ATM                        3
# ClubHouse                  3
# School                     3
# 24X7Security               3
# PowerBackup                3
# CarParking                 3
# StaffQuarter               3
# Cafeteria                  3
# MultipurposeRoom           3
# Hospital                   3
# WashingMachine             3
# Gasconnection              3
# AC                         3
# Wifi                       3
# Children'splayarea         3
# LiftAvailable              3
# BED                        3
# VaastuCompliant            3
# Microwave                  3
# GolfCourse                 3
# TV                         3
# DiningTable                3
# Sofa                       3
# Wardrobe                   3
# Refrigerator               3
# Price                   4510
# dtype: int64

# %%
df_train.select_dtypes(exclude=['number']).columns
# Out:
# Index(['Location'], dtype='object')

# %%
# @title Drop: id, Location in train set
df_train = df_train.drop(['Location', 'id'], axis=1)

# %%
df_train
# Out:
#        Area  No. of Bedrooms  Resale  MaintenanceStaff  Gymnasium  \
# 0       964                3       0                 9          9
# 1      1075                2       1                 1          1
# 2      2092                3       0                 1          1
# 3      1174                2       1                 9          9
# 4      1380                2       1                 9          9
# ...     ...              ...     ...               ...        ...
# 26365  1060                2       1                 9          9
# 26366  1250                3       1                 0          0
# 26367   440                1       0                 0          0
# 26368   875                2       0                 0          1
# 26369  1080                3       0                 9          9
#
#        SwimmingPool  LandscapedGardens  JoggingTrack  RainWaterHarvesting  \
# 0                 9                  9             9                    9
# 1                 0                  0             0                    0
# 2                 1                  1             0                    1
# 3                 9                  9             9                    9
# 4                 9                  9             9                    9
# ...             ...                ...           ...                  ...
# 26365             9                  9             9                    9
# 26366             0                  0             0                    0
# 26367             0                  1             0                    0
# 26368             1                  0             1                    0
# 26369             9                  9             9                    9
#
#        IndoorGames  ...  BED  VaastuCompliant  Microwave  GolfCourse  TV  \
# 0                9  ...    9                9          9           9   9
# 1                0  ...    1                0          0           0   0
# 2                1  ...    0                1          0           0   0
# 3                9  ...    9                9          9           9   9
# 4                9  ...    9                9          9           9   9
# ...            ...  ...  ...              ...        ...         ...  ..
# 26365            9  ...    9                9          9           9   9
# 26366            0  ...    0                0          1           0   0
# 26367            0  ...    0                0          0           0   0
# 26368            1  ...    0                0          0           0   0
# 26369            9  ...    9                9          9           9   9
#
#        DiningTable  Sofa  Wardrobe  Refrigerator     Price
# 0                9     9         9             9   7500000
# 1                0     0         0             0   6200000
# 2                0     0         0             0  10400000
# 3                9     9         9             9  18600000
# 4                9     9         9             9   9500000
# ...            ...   ...       ...           ...       ...
# 26365            9     9         9             9   2400000
# 26366            0     0         0             0  18900000
# 26367            0     0         0             0   3700000
# 26368            0     0         0             0   4790000
# 26369            9     9         9             9   6000000
#
# [26370 rows x 39 columns]

# %%
corr = df_train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_81209_row0_col0, #T_81209_row1_col1, #T_81209_row2_col2, #T_81209_row3_col3, #T_81209_row3_col4, #T_81209_row3_col5, #T_81209_row3_col6, #T_81209_row3_col7, #T_81209_row3_col8, #T_81209_row3_col9, #T_81209_row3_col10, #T_81209_row3_col11, #T_81209_row3_col12, #T_81209_row3_col13, #T_81209_row3_col14, #T_81209_row3_col15, #T_81209_row3_col16, #T_81209_row3_col17, #T_81209_row3_col18, #T_81209_row3_col19, #T_81209_row3_col20, #T_81209_row3_col21, #T_81209_row3_col22, #T_81209_row3_col23, #T_81209_row3_col24, #T_81209_row3_col25, #T_81209_row3_col26, #T_81209_row3_col27, #T_81209_row3_col28, #T_81209_row3_col29, #T_81209_row3_col30, #T_81209_row3_col31, #T_81209_row3_col32, #T_81209_row3_col33, #T_81209_row3_col34, #T_81209_row3_col35, #T_81209_row3_col36, #T_81209_row3_col37, #T_81209_row4_col3, #T_81209_row4_col4, #T_81209_row4_col5, #T_81209_row4_col6, #T_81209_row4_col7, #T_81209_row4_col8, #T_81209_row4_col9, #T_81209_row4_col10, #T_81209_row4_col11, #T_81209_row4_col12, #T_81209_row4_col13, #T_81209_row4_col14, #T_81209_row4_col15, #T_81209_row4_col16, #T_81209_row4_col17, #T_81209_row4_col18, #T_81209_row4_col19, #T_81209_row4_col20, #T_81209_row4_col21, #T_81209_row4_col22, #T_81209_row4_col23, #T_81209_row4_col24, #T_81209_row4_col25, #T_81209_row4_col26, #T_81209_row4_col27, #T_81209_row4_col28, #T_81209_row4_col29, #T_81209_row4_col30, #T_81209_row4_col31, #T_81209_row4_col32, #T_81209_row4_col33, #T_81209_row4_col34, #T_81209_row4_col35, #T_81209_row4_col36, #T_81209_row4_col37, #T_81209_row5_col3, #T_81209_row5_col4, #T_81209_row5_col5, #T_81209_row5_col6, #T_81209_row5_col7, #T_81209_row5_col8, #T_81209_row5_col9, #T_81209_row5_col10, #T_81209_row5_col11, #T_81209_row5_col12, #T_81209_row5_col13, #T_81209_row5_col14, #T_81209_row5_col15, #T_81209_row5_col16, #T_81209_row5_col17, #T_81209_row5_col18, #T_81209_row5_col19, #T_81209_row5_col20, #T_81209_row5_col21, #T_81209_row5_col22, #T_81209_row5_col23, #T_81209_row5_col24, #T_81209_row5_col25, #T_81209_row5_col26, #T_81209_row5_col27, #T_81209_row5_col28, #T_81209_row5_col29, #T_81209_row5_col30, #T_81209_row5_col31, #T_81209_row5_col32, #T_81209_row5_col33, #T_81209_row5_col34, #T_81209_row5_col35, #T_81209_row5_col36, #T_81209_row5_col37, #T_81209_row6_col3, #T_81209_row6_col4, #T_81209_row6_col5, #T_81209_row6_col6, #T_81209_row6_col7, #T_81209_row6_col8, #T_81209_row6_col9, #T_81209_row6_col10, #T_81209_row6_col11, #T_81209_row6_col12, #T_81209_row6_col13, #T_81209_row6_col14, #T_81209_row6_col15, #T_81209_row6_col16, #T_81209_row6_col17, #T_81209_row6_col18, #T_81209_row6_col19, #T_81209_row6_col20, #T_81209_row6_col21, #T_81209_row6_col22, #T_81209_row6_col23, #T_81209_row6_col24, #T_81209_row6_col25, #T_81209_row6_col26, #T_81209_row6_col27, #T_81209_row6_col28, #T_81209_row6_col29, #T_81209_row6_col30, #T_81209_row6_col31, #T_81209_row6_col32, #T_81209_row6_col33, #T_81209_row6_col34, #T_81209_row6_col35, #T_81209_row6_col36, #T_81209_row6_col37, #T_81209_row7_col3, #T_81209_row7_col4, #T_81209_row7_col5, #T_81209_row7_col6, #T_81209_row7_col7, #T_81209_row7_col8, #T_81209_row7_col9, #T_81209_row7_col10, #T_81209_row7_col11, #T_81209_row7_col12, #T_81209_row7_col13, #T_81209_row7_col14, #T_81209_row7_col15, #T_81209_row7_col16, #T_81209_row7_col17, #T_81209_row7_col18, #T_81209_row7_col19, #T_81209_row7_col20, #T_81209_row7_col21, #T_81209_row7_col22, #T_81209_row7_col23, #T_81209_row7_col24, #T_81209_row7_col25, #T_81209_row7_col26, #T_81209_row7_col27, #T_81209_row7_col28, #T_81209_row7_col29, #T_81209_row7_col30, #T_81209_row7_col31, #T_81209_row7_col32, #T_81209_row7_col33, #T_81209_row7_col34, #T_81209_row7_col35, #T_81209_row7_col36, #T_81209_row7_col37, #T_81209_row8_col3, #T_81209_row8_col4, #T_81209_row8_col5, #T_81209_row8_col6, #T_81209_row8_col7, #T_81209_row8_col8, #T_81209_row8_col9, #T_81209_row8_col10, #T_81209_row8_col11, #T_81209_row8_col12, #T_81209_row8_col13, #T_81209_row8_col14, #T_81209_row8_col15, #T_81209_row8_col16, #T_81209_row8 ...

# %% [markdown]
# # Train, Val, Test split

# %%
X = df_train.drop('Price', axis=1)
y = df_train['Price']

# %%
# calculate interquartile range
q25, q75 = percentile(y, 25), percentile(y, 75)
iqr = q75 - q25
cut_off = iqr * 1.5
lower, upper = q25 - cut_off, q75 + cut_off

cond = (y >= lower) & (y <= upper)

X = X[cond]
y = y[cond]
X = X.reset_index(drop=True)  # Reset index starting from 0
y = y.reset_index(drop=True)  # Reset index starting from 0

# %% [markdown]
# ## Random Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))  # Create 2-row subplot for efficient layout

# Plot training data histogram with KDE (horizontal)
sns.histplot(y_train, kde=True, ax=axes[0])
axes[0].set_title("Training Price Distribution")
axes[0].set_xlabel("Price")  # Adjust for horizontal orientation
axes[0].set_ylabel("Density")

# Plot testing data histogram with KDE (horizontal)
sns.histplot(y_test, kde=True, ax=axes[1])
axes[1].set_title("Testing Price Distribution")
axes[1].set_xlabel("Density")  # Adjust for horizontal orientation
axes[1].set_ylabel("Price")

# Optional layout refinement
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Stratified Splitting

# %%
n_group = 4
grp = pd.cut(y, n_group, labels=list(range(n_group)))
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=40)
for i, (train_index, test_index) in enumerate(sss.split(X, grp)):
  pass

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))  # Create 2-row subplot for efficient layout

# Plot training data histogram with KDE (horizontal)
sns.histplot(y[train_index], kde=True, ax=axes[0])
axes[0].set_title("Training Price Distribution")
axes[0].set_xlabel("Density")  # Adjust for horizontal orientation
axes[0].set_ylabel("Price")

# Plot testing data histogram with KDE (horizontal)
sns.histplot(y[test_index], kde=True, ax=axes[1])
axes[1].set_title("Testing Price Distribution")
axes[1].set_xlabel("Density")  # Adjust for horizontal orientation
axes[1].set_ylabel("Price")

# Optional layout refinement
plt.tight_layout()

plt.show()

# %%
X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y[train_index], y[test_index]

# %%
# @title MinMaxScaler X
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
y_train = np.array(y_train).reshape(-1, 1)
y_test = np.array(y_test).reshape(-1, 1)

# %% [markdown]
# # Define K-Fold cross validation function

# %%
def cross_validation(x_train, y_train, model, n_folds=5, random_state=42):
  cv = KFold(n_splits=n_folds, random_state=random_state, shuffle=True)
  scores = []

  for train_index, test_index in cv.split(x_train):
      X_train_fold, X_test_fold, y_train_fold, y_test_fold = x_train[train_index], x_train[test_index], y_train[train_index], y_train[test_index]

      model.fit(X_train_fold, y_train_fold.ravel())

      y_predict = model.predict(X_test_fold)

      r2 = r2_score(y_test_fold, y_predict)

      scores.append(r2)

  return scores, np.mean(scores)

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import KFold

from prettytable import PrettyTable
import xgboost as xg

import multiprocessing

# %%
lrmodel = LinearRegression()
scores, avg_ = cross_validation(x_train=X_train, y_train=y_train, model=lrmodel, n_folds=5, random_state=42)

print("R2: ", scores)
print("Average R2:", avg_)
# Out:
# R2:  [0.12547252451855384, 0.13342895895725715, 0.12154838337356533, 0.1412855147832094, 0.11135716928319428]
# Average R2: 0.126618510183156

# %% [markdown]
# # Xgboost

# %%
xgb_r = xg.XGBRegressor(objective ='reg:squarederror', n_estimators = 5, seed = 42)
scores, avg_ = cross_validation(x_train=X_train, y_train=y_train, model=xgb_r, n_folds=5, random_state=42)

print("R2: ", scores)
print("Average R2:", avg_)
# Out:
# R2:  [0.2495929484852083, 0.26368714373018476, 0.2482646007823398, 0.2638559937267648, 0.2457356798515391]
# Average R2: 0.25422727331520734

# %% [markdown]
# # K-fold for hyperparameter tuning Xgboost

# %%
# Define parameter list
n_estimators = list(range(11))
lr = list(map(lambda x: x/10, list(range(5, 16, 1))))

hyperparameter_score_list = []
for n_estimator in n_estimators:
  for learning_rate in lr:
    xgb_r = xg.XGBRegressor(objective ='reg:squarederror', n_estimators=n_estimator, learning_rate=learning_rate, seed = 42)
    scores, avg_ = cross_validation(x_train=X_train, y_train=y_train, model=xgb_r, n_folds=5, random_state=42)
    hyperparameter_score_list.append((n_estimator, learning_rate, avg_))

# %%
best_params = max(hyperparameter_score_list, key=lambda x: x[2])
print(best_params)
# Out:
# (10, 0.5, 0.2744917005359418)

# %%
myTable = PrettyTable(["Number of estimator", "Learning rate", "Average R2 score"])
for row in hyperparameter_score_list:
    myTable.add_row([row[0], row[1], round(row[2],3)])
print(myTable)
# Out:
# +---------------------+---------------+------------------+
# | Number of estimator | Learning rate | Average R2 score |
# +---------------------+---------------+------------------+
# |          0          |      0.5      |      -3.012      |
# |          0          |      0.6      |      -3.012      |
# |          0          |      0.7      |      -3.012      |
# |          0          |      0.8      |      -3.012      |
# |          0          |      0.9      |      -3.012      |
# |          0          |      1.0      |      -3.012      |
# |          0          |      1.1      |      -3.012      |
# |          0          |      1.2      |      -3.012      |
# |          0          |      1.3      |      -3.012      |
# |          0          |      1.4      |      -3.012      |
# |          0          |      1.5      |      -3.012      |
# |          1          |      0.5      |      0.184       |
# |          1          |      0.6      |      0.206       |
# |          1          |      0.7      |      0.222       |
# |          1          |      0.8      |      0.234       |
# |          1          |      0.9      |       0.24       |
# |          1          |      1.0      |      0.242       |
# |          1          |      1.1      |      0.238       |
# |          1          |      1.2      |      0.229       |
# |          1          |      1.3      |      0.216       |
# |          1          |      1.4      |      0.197       |
# |          1          |      1.5      |      0.173       |
# |          2          |      0.5      |      0.238       |
# |          2          |      0.6      |      0.249       |
# |          2          |      0.7      |      0.257       |
# |          2          |      0.8      |      0.257       |
# |          2          |      0.9      |      0.257       |
# |          2          |      1.0      |      0.255       |
# |          2          |      1.1      |      0.251       |
# |          2          |      1.2      |      0.246       |
# |          2          |      1.3      |       0.24       |
# |          2          |      1.4      |      0.233       |
# |          2          |      1.5      |      0.223       |
# |          3          |      0.5      |      0.258       |
# |          3          |      0.6      |       0.26       |
# |          3          |      0.7      |      0.264       |
# |          3          |      0.8      |      0.263       |
# |          3          |      0.9      |      0.258       |
# |          3          |      1.0      |      0.257       |
# |          3          |      1.1      |      0.253       |
# |          3          |      1.2      |      0.246       |
# |          3          |      1.3      |      0.243       |
# |          3          |      1.4      |      0.237       |
# |          3          |      1.5      |      0.233       |
# |          4          |      0.5      |      0.265       |
# |          4          |      0.6      |      0.266       |
# |          4          |      0.7      |      0.266       |
# |          4          |      0.8      |      0.263       |
# |          4          |      0.9      |       0.26       |
# |          4          |      1.0      |      0.258       |
# |          4          |      1.1      |      0.255       |
# |          4          |      1.2      |       0.25       |
# |          4          |      1.3      |      0.244       |
# |          4          |      1.4      |      0.238       |
# |          4          |      1.5      |      0.236       |
# |          5          |      0.5      |      0.269       |
# |          5          |      0.6      |      0.266       |
# |          5          |      0.7      |      0.267       |
# |          5          |      0.8      |      0.266       |
# |          5          |      0.9      |      0.262       |
# |          5          |      1.0      |      0.261       |
# |          5          |      1.1      |      0.256       |
# |          5          |      1.2      |      0.249       |
# |          5          |      1.3      |      0.243       |
# |          5          |      1.4      |      0.238       |
# |          5          |      1.5      |      0.235       |
# |          6          |      0.5      |      0.271       |
# |          6          |      0.6      |      0.268       |
# |          6          |      0.7      |      0.269       |
# |          6          |      0.8      |      0.266       |
# |          6          |      0.9      |      0.263       |
# |          6          |      1.0      |      0.261       |
# |          6          |      1.1      |      0.256       |
# |          6          |      1.2      |      0.247       |
# |          6          |      1.3      |      0.242       |
# |          6          |      1.4      |      0.234       |
# |          6          |      1.5      |      0.233       |
# |          7          |      0.5      |      0.273       |
# |          7          |      0.6      |      0.269       |
# |          7          |      0.7      |      0.271       |
# |          7          |      0.8      |      0.268       |
# |          7          |      0.9      |      0.264       |
# |          7          |      1.0      |      0.261       |
# |          7          |      1.1      |      0.257       |
# |          7          |      1.2      |      0.246       |
# |          7          |      1.3      |      0.241       |
# |          7          |      1.4      |      0.237       |
# |          7          |      1.5      |      0.231       |
# |          8          |      0.5      |      0.274       |
# |          8          |      0.6      |      0.271       |
# |          8          |      0.7      |       0.27       |
# |          8          |      0.8      |      0.268       |
# |          8          |      0.9      |      0.264       |
# |          8          |      1.0      |      0.262       |
# |          8          |      1.1      |      0.256       |
# |          8          |      1.2      |      0.244       |
# |          8          |      1.3      |      0.241       |
# |          8          |      1.4      |      0.234       |
# |          8          |      1.5      |       0.23       |
# |          9          |      0.5      |      0.274       |
# |          9          |      0.6      |      0.272       |
# |          9          |      0.7      |       0.27       |
# |          9          |      0.8      |      0.269       |
# |          9          |      0.9      |      0.264       |
# |          9          |      1.0      |      0.262       |
# |          9          |      1.1      |      0.253       |
# |          9          |      1.2      |      0.244       |
# |          9          |      1.3      |      0.241       |
# |          9          |      1.4      |      0.231       |
# |          9          |      1.5      |      0.229       |
# |          10         |      0.5      |      0.274       |
# |          10         |      0.6      |      0.273       |
# |          10         |      0.7      |      0.271       |
# |          10         |      0.8      |      0.268       |
# |          10         |      0.9      |      0.265       |
# |          10         |      1.0      |      0.261       |
# |          10         |      1.1      |      0.254       |
# |          10         |      1.2      |      0.243       |
# |          10         |      1.3      |      0.239       |
# |          10         |      1.4      |       0.23       |
# |          10         |      1.5      |      0.229       |
# +---------------------+---------------+------------------+

# %% [markdown]
# # Test set

# %%
lrmodel = LinearRegression()
lrmodel.fit(X_train, y_train)
y_predict = lrmodel.predict(X_test)
r2 = r2_score(y_test, y_predict)
print(r2)
# Out:
# 0.10871111840712566

# %%
xgb_r = xg.XGBRegressor(objective ='reg:squarederror', n_estimators=best_params[0], learning_rate=best_params[1], seed = 42)
xgb_r.fit(X_train, y_train)
y_predict = xgb_r.predict(X_test)
r2 = r2_score(y_test, y_predict)
print(r2)
# Out:
# 0.3018943120934371

# %%
xgb_r = xg.XGBRegressor(objective ='reg:squarederror', n_estimators=5, seed = 42)
xgb_r.fit(X_train, y_train)
y_predict = xgb_r.predict(X_test)
r2 = r2_score(y_test, y_predict)
print(r2)
# Out:
# 0.2728789817930327
